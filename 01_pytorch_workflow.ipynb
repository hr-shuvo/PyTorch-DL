# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

torch.__version__
# Out:
# '2.5.1'

# %% [markdown]
# ## Data

# %%
weight = 0.7
bias = 0.3

start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(1)
y = weight * X + bias

X[:10], y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %%
len(X), len(y)
# Out:
# (50, 50)

# %%
train_split = int(0.8 * len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
X.shape, X_train.shape
# Out:
# (torch.Size([50, 1]), torch.Size([40, 1]))

# %%
def plot_predictions(train_data=X_train,
                     train_labels=y_train,
                     test_data=X_test,
                     test_labels=y_test,
                     predictions=None):
  plt.figure(figsize=(10, 7))
  plt.scatter(train_data, train_labels, c='b', s=10, label='training data')
  plt.scatter(test_data, test_labels, c='g', s=10, label='test data')

  if predictions is not None:
      plt.scatter(test_data, predictions, c='r', s=10, label='predictions')

  plt.legend(prop={"size": 14})

# %%
 plot_predictions()

# %% [markdown]
# ## Build model

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))

        self.bias = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))

    def forward(self, x:torch.tensor) -> torch.Tensor:
        return self.weights * x + self.bias

# %% [markdown]
# ## Checking contents of the model

# %%
torch.manual_seed(42)

model_0 = LinearRegressionModel()

list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %% [markdown]
# ## Making prediction using `torch.inference_mode()`

# %%
y_preds = model_0(X_test)
y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]], grad_fn=<AddBackward0>)

# %%
with torch.inference_mode():
    y_preds = model_0(X_test)

y_preds
# Out:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
y_test
# Out:
# tensor([[0.8600],
#         [0.8740],
#         [0.8880],
#         [0.9020],
#         [0.9160],
#         [0.9300],
#         [0.9440],
#         [0.9580],
#         [0.9720],
#         [0.9860]])

# %%
plot_predictions(predictions=y_preds)

# %% [markdown]
# ## Train model

# %%
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
loss_fn = nn.L1Loss()

optimizer = torch.optim.SGD(params=model_0.parameters(), lr=0.01)

# %%
torch.manual_seed(42)

epochs = 200

epoch_count = []
loss_values = []
test_loss_values = []

for epoch in range(epochs):
    model_0.train()

    y_pred = model_0(X_train)

    loss = loss_fn(y_pred, y_train)
    # print('loss: {}'.format(loss))

    optimizer.zero_grad()

    loss.backward()

    optimizer.step()

    model_0.eval()

    with torch.inference_mode():
        test_pred = model_0(X_test)

        test_loss = loss_fn(test_pred, y_test)

    if epoch % 10 == 0:
        epoch_count.append(epoch)
        loss_values.append(loss)
        test_loss_values.append(test_loss)
        print(f"Epoch: {epoch} | Loss: {loss} | Test loss: {test_loss}")
        # Print out model state_dict()
        # print(model_0.state_dict())
# Out:
# Epoch: 0 | Loss: 0.31288138031959534 | Test loss: 0.48106518387794495
# Epoch: 10 | Loss: 0.1976713240146637 | Test loss: 0.3463551998138428
# Epoch: 20 | Loss: 0.08908725529909134 | Test loss: 0.21729660034179688
# Epoch: 30 | Loss: 0.053148526698350906 | Test loss: 0.14464017748832703
# Epoch: 40 | Loss: 0.04543796554207802 | Test loss: 0.11360953003168106
# Epoch: 50 | Loss: 0.04167863354086876 | Test loss: 0.09919948130846024
# Epoch: 60 | Loss: 0.03818932920694351 | Test loss: 0.08886633068323135
# Epoch: 70 | Loss: 0.03476089984178543 | Test loss: 0.0805937647819519
# Epoch: 80 | Loss: 0.03132382780313492 | Test loss: 0.07232122868299484
# Epoch: 90 | Loss: 0.02788739837706089 | Test loss: 0.06473556160926819
# Epoch: 100 | Loss: 0.024458957836031914 | Test loss: 0.05646304413676262
# Epoch: 110 | Loss: 0.021020207554101944 | Test loss: 0.04819049686193466
# Epoch: 120 | Loss: 0.01758546568453312 | Test loss: 0.04060482233762741
# Epoch: 130 | Loss: 0.014155393466353416 | Test loss: 0.03233227878808975
# Epoch: 140 | Loss: 0.010716589167714119 | Test loss: 0.024059748277068138
# Epoch: 150 | Loss: 0.0072835334576666355 | Test loss: 0.016474086791276932
# Epoch: 160 | Loss: 0.0038517764769494534 | Test loss: 0.008201557211577892
# Epoch: 170 | Loss: 0.008932482451200485 | Test loss: 0.005023092031478882
# Epoch: 180 | Loss: 0.008932482451200485 | Test loss: 0.005023092031478882
# Epoch: 190 | Loss: 0.008932482451200485 | Test loss: 0.005023092031478882

# %%
import numpy as np

np.array(torch.tensor(loss_values).numpy()), test_loss_values
# Out:
# (array([0.31288138, 0.19767132, 0.08908726, 0.05314853, 0.04543797,
#         0.04167863, 0.03818933, 0.0347609 , 0.03132383, 0.0278874 ,
#         0.02445896, 0.02102021, 0.01758547, 0.01415539, 0.01071659,
#         0.00728353, 0.00385178, 0.00893248, 0.00893248, 0.00893248],
#        dtype=float32),
#  [tensor(0.4811),
#   tensor(0.3464),
#   tensor(0.2173),
#   tensor(0.1446),
#   tensor(0.1136),
#   tensor(0.0992),
#   tensor(0.0889),
#   tensor(0.0806),
#   tensor(0.0723),
#   tensor(0.0647),
#   tensor(0.0565),
#   tensor(0.0482),
#   tensor(0.0406),
#   tensor(0.0323),
#   tensor(0.0241),
#   tensor(0.0165),
#   tensor(0.0082),
#   tensor(0.0050),
#   tensor(0.0050),
#   tensor(0.0050)])

# %%
plt.plot(epoch_count, np.array(torch.tensor(loss_values).numpy()), label="Train loss")
plt.plot(epoch_count, test_loss_values, label="Test loss")
plt.title("Training and test loss curves")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend();

# %%
with torch.inference_mode():
  y_pred_new = model_0(X_test)

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.6990])), ('bias', tensor([0.3093]))])

# %%
weight, bias
# Out:
# (0.7, 0.3)

# %%
plot_predictions(predictions=y_pred)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 plot_predictions(predictions=y_pred)
#
# Cell In[124], line 11, in plot_predictions(train_data, train_labels, test_data, test_labels, predictions)
#       8 plt.scatter(test_data, test_labels, c='g', s=10, label='test data')
#      10 if predictions is not None:
# ---> 11     plt.scatter(test_data, predictions, c='r', s=10, label='predictions')
#      13 plt.legend(prop={"size": 14})
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\pyplot.py:3937, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3917 @_copy_docstring_and_deprecators(Axes.scatter)
#    3918 def scatter(
#    3919     x: float | ArrayLike,
#    (...)   3935     **kwargs,
#    3936 ) -> PathCollection:
# -> 3937     __ret = gca().scatter(
#    3938         x,
#    3939         y,
#    3940         s=s,
#    3941         c=c,
#    3942         marker=marker,
#    3943         cmap=cmap,
#    3944         norm=norm,
#    3945         vmin=vmin,
#    3946         vmax=vmax,
#    3947         alpha=alpha,
#    3948         linewidths=linewidths,
#    3949         edgecolors=edgecolors,
#    3950         colorizer=colorizer,
#    3951         plotnonfinite=plotnonfinite,
#    3952         **({"data": data} if data is not None else {}),
#    3953         **kwargs,
#    3954     )
#    3955     sci(__ret)
#    3956     return __ret
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\axes\_axes.py:4924, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4922 edgecolors = kwargs.pop('edgecolor', None)
#    4923 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4924 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4925 # np.ma.ravel yields an ndarray, not a masked array,
#    4926 # unless its argument is a masked array.
#    4927 x = np.ma.ravel(x)
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\axes\_base.py:2647, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2645     # Update from data if axis is already set but no unit is set yet.
#    2646     if axis is not None and data is not None and not axis.have_units():
# -> 2647         axis.update_units(data)
#    2648 for axis_name, axis in axis_map.items():
#    2649     # Return if no axis is set.
#    2650     if axis is None:
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\axis.py:1745, in Axis.update_units(self, data)
#    1739 """
#    1740 Introspect *data* for units converter and update the
#    1741 ``axis.get_converter`` instance if necessary. Return *True*
#    1742 if *data* is registered for unit conversion.
#    1743 """
#    1744 if not self._converter_is_explicit:
# -> 1745     converter = munits.registry.get_converter(data)
#    1746 else:
#    1747     converter = self._converter
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\units.py:167, in Registry.get_converter(self, x)
#     165 """Get the converter interface instance for *x*, or None."""
#     166 # Unpack in case of e.g. Pandas or xarray object
# --> 167 x = cbook._unpack_to_numpy(x)
#     169 if isinstance(x, np.ndarray):
#     170     # In case x in a masked array, access the underlying data (only its
#     171     # type matters).  If x is a regular ndarray, getdata() just returns
#     172     # the array itself.
#     173     x = np.ma.getdata(x).ravel()
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\matplotlib\cbook.py:2371, in _unpack_to_numpy(x)
#    2365         return xtmp
#    2366 if _is_torch_array(x) or _is_jax_array(x) or _is_tensorflow_array(x):
#    2367     # using np.asarray() instead of explicitly __array__(), as the latter is
#    2368     # only _one_ of many methods, and it's the last resort, see also
#    2369     # https://numpy.org/devdocs/user/basics.interoperability.html#using-arbitrary-objects-in-numpy
#    2370     # therefore, let arrays do better if they can
# -> 2371     xtmp = np.asarray(x)
#    2373     # In case np.asarray method does not return a numpy array in future
#    2374     if isinstance(xtmp, np.ndarray):
#
# File d:\installed\Program Files\anaconda3\envs\ml\Lib\site-packages\torch\_tensor.py:1149, in Tensor.__array__(self, dtype)
#    1147     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1148 if dtype is None:
# -> 1149     return self.numpy()
#    1150 else:
#    1151     return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %%
plot_predictions(predictions=y_pred_new)
